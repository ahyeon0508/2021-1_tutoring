# %% [markdown]
# 📖 참고, 데이터 : Do it! 데이터 분석을 위한 판다스 입문

# %% [markdown]
# # 판다스 데이터프레임과 시리즈

# %% [markdown]
# # 1. 데이터 만들기

# %%
import pandas as pd
s = pd.Series(['banana', 42])
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
s = pd.Series(["Ahyeon", 24],index=["name", "age"] )
print(s)
# Out:
# name    Ahyeon
# age         24
# dtype: object

# %%
people = pd.DataFrame({
    "Name":['ahyeon','gahyeon'],
    "Age":[24,22],
    "Born":["1988-05-08", "2000-07-24"],
    "Like" : ["baseball", "soccer"]

})

# %%
people
# Out:
#       Name  Age        Born      Like
# 0   ahyeon   24  1988-05-08  baseball
# 1  gahyeon   22  2000-07-24    soccer

# %%
scientists = pd.DataFrame( 
    data = {"Occupation":['chemist','Statistician'],
           'Born' : ['1920-07-25','1876-03-13'],
           'Age' : [37,61],
           'Died' : ['1958-04','1937-10-16']},
    index=["Rosaline Frankil", "William Gosset"],
    columns=['Occupation', 'Born', 'Age', 'Died']) 
print(scientists)
# Out:
#                     Occupation        Born  Age        Died
# Rosaline Frankil       chemist  1920-07-25   37     1958-04
# William Gosset    Statistician  1876-03-13   61  1937-10-16

# %%
# 딕셔너리는 순서 보장x
from collections import OrderedDict

scientists = pd.DataFrame(OrderedDict([ 
    ('Name', ['Rosaline Franklin', 'William Gosset']),
    ('Occupation', ['Chemist', 'Statistician']), 
    ('Born', ['1920-07-25', '1876-06-13']), 
    ('Died', ['1958-04-16', '1937-10-16']), 
    ('Age', [37, 61])
])
) 
print(scientists)
# Out:
#                 Name    Occupation        Born        Died  Age
# 0  Rosaline Franklin       Chemist  1920-07-25  1958-04-16   37
# 1     William Gosset  Statistician  1876-06-13  1937-10-16   61

# %% [markdown]
# # 2. 시리즈

# %%
scientists = pd.DataFrame( 
    data={'Occupation': ['Chemist', 'Statistician'], 
          'Born': ['1920-07-25', '1876-06-13'], 
          'Died': ['1958-04-16', '1937-10-16'],
          'Age': [37, 61]},
    index=['Rosaline Franklin', 'William Gosset'],
    columns=['Occupation', 'Born', 'Age', 'Died']) 
print(scientists)
# Out:
#                      Occupation        Born  Age        Died
# Rosaline Franklin       Chemist  1920-07-25   37  1958-04-16
# William Gosset     Statistician  1876-06-13   61  1937-10-16

# %%
first_row = scientists.loc['William Gosset']
print(type(first_row)) # Age의 자료형 무시됨, 세로로 나타나지기 때문에 Series
# Out:
# <class 'pandas.core.series.Series'>

# %%
first_row.index
# Out:
# Index(['Occupation', 'Born', 'Age', 'Died'], dtype='object')

# %%
first_row.values
# Out:
# array(['Statistician', '1876-06-13', 61, '1937-10-16'], dtype=object)

# %%
first_row.keys() # 속성이 아니라 메소드
# Out:
# Index(['Occupation', 'Born', 'Age', 'Died'], dtype='object')

# %%
first_row.index[0]
# Out:
# 'Occupation'

# %%
first_row.keys()[0]
# Out:
# 'Occupation'

# %%
# Age의 평균을 구하시오
scientists['Age'].mean()
# Out:
# 49.0

# %% [markdown]
# ## 불린 추출

# %%
scientists = pd.read_csv('data/scientists.csv') #파일열기

# %%
ages = scientists['Age']
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
ages.mean()
# Out:
# 59.125

# %%
ages[ages > ages.mean()] #괄호 안에가 true, false로 바뀜
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
ages > ages.mean() #불린 형식
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
manual_bool_values = [True, True, False, False, True, True, False, True] 
print(ages[manual_bool_values])
# Out:
# 0    37
# 1    61
# 4    56
# 5    45
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# ## 시리즈와 브로드캐스팅

# %%
ages + pd.Series([1, 101]) # 나머지는 더할 것이 없어서 NaN은 누락값임
# Out:
# 0     38.0
# 1    162.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# dtype: float64

# %% [markdown]
# ## Sort

# %%
ages.sort_index(ascending=False) # 데이터의 역순이 아니라 인덱스의 역순임  
#false 내림차순, ture 올림차순
# Out:
# 7    77
# 6    41
# 5    45
# 4    56
# 3    66
# 2    90
# 1    61
# 0    37
# Name: Age, dtype: int64

# %%
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
rev_ages = ages.sort_index(ascending=False)

ages + rev_ages # 일치하는 인덱스끼리 연산
# Out:
# 0     74
# 1    122
# 2    180
# 3    132
# 4    112
# 5     90
# 6     82
# 7    154
# Name: Age, dtype: int64

# %% [markdown]
# # 3. 데이터프레임

# %%
scientists[scientists['Age'] > scientists['Age'].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
print(scientists * 2)
# Out:
#                                        Name                  Born  \
# 0        Rosaline FranklinRosaline Franklin  1920-07-251920-07-25
# 1              William GossetWilliam Gosset  1876-06-131876-06-13
# 2  Florence NightingaleFlorence Nightingale  1820-05-121820-05-12
# 3                    Marie CurieMarie Curie  1867-11-071867-11-07
# 4                Rachel CarsonRachel Carson  1907-05-271907-05-27
# 5                        John SnowJohn Snow  1813-03-151813-03-15
# 6                    Alan TuringAlan Turing  1912-06-231912-06-23
# 7                  Johann GaussJohann Gauss  1777-04-301777-04-30
#
#                    Died  Age                            Occupation
# 0  1958-04-161958-04-16   74                        ChemistChemist
# 1  1937-10-161937-10-16  122              StatisticianStatistician
# 2  1910-08-131910-08-13  180                            NurseNurse
# 3  1934-07-041934-07-04  132                        ChemistChemist
# ...

# %% [markdown]
# # 3. 데이터 처리하기

# %%
print(scientists['Born'].dtype)
print(type(scientists['Died']))
print(scientists['Died'].dtype)
# Out:
# object
# <class 'pandas.core.series.Series'>
# object

# %% [markdown]
# ## to_datetime 이용해서 datetime형으로 바꾸기
# - pd.to_date(data, format=형식)

# %%
born_datetime = pd.to_datetime(scientists['Born'],format="%y-%m-%d")
born_datetime
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449             try:
# --> 450                 values, tz = conversion.datetime_to_datetime64(arg)
#     451                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-7e9358a6e4fa> in <module>
# ----> 1 born_datetime = pd.to_datetime(scientists['Born'],format="%y-%m-%d")
#       2 born_datetime
#
# ...

# %%
died_datetime = pd.to_datetime(scientists['Died'],format="%y-%m,%d")
print(died_datetime)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449             try:
# --> 450                 values, tz = conversion.datetime_to_datetime64(arg)
#     451                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-5abff0bea51f> in <module>
# ----> 1 died_datetime = pd.to_datetime(scientists['Died'],format="%y-%m,%d")
#       2 print(died_datetime)
#
# ...

# %%
scientists['born_dt'], scientists['died_dt'] = born_datetime, died_datetime
print(scientists.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-e7957c946fbd> in <module>
# ----> 1 scientists['born_dt'], scientists['died_dt'] = born_datetime, died_datetime
#       2 print(scientists.head())
#
# NameError: name 'born_datetime' is not defined

# %%
scientists['age_days_dt'] = (scientists['died_dt'] - scientists['born_dt'])
print(scientists)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'died_dt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-df8cc2524aae> in <module>
# ...

# %%
print(scientists.columns)
# Out:
# Index(['Name', 'Born', 'Died', 'Age', 'Occupation'], dtype='object')

# %%
scientists_dropped = scientists.drop(['Age'], axls=1)

print(scientists_dropped.columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-27540ca06f03> in <module>
# ----> 1 scientists_dropped = scientists.drop(['Age'], axls=1)
#       2
#       3 print(scientists_dropped.columns)
#
# TypeError: drop() got an unexpected keyword argument 'axls'

# %% [markdown]
# # 4. 데이터 저장하고 불러오기

# %% [markdown]
# - 피클 : 데이터를 바이너리 형태로 직렬화한 오브젝트를 저장하는 방법으로 스프레드시트보다 더 작은 용량으로 데이터를 저장할 수 있어 매우 편리

# %%
names = scientists['Name']
names.to_pickle('output/scientists_names_series.pickle')

# %%
scientists.to_pickle('output/scientists_df.pickle')

# %%
scientist_names_from_pickle = pd.read_pickle('output/scientists_names_series.pickle')
print(scientist_names_from_pickle)
# Out:
# 0       Rosaline Franklin
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 4           Rachel Carson
# 5               John Snow
# 6             Alan Turing
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
scientists_from_pickle = pd.read_pickle('output/scientists_df.pickle')
print(scientists_from_pickle)
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %% [markdown]
# ## CSV 파일과 TSV 파일로 저장하기

# %%
names.to_csv('output/scientist_names_series.csv')

# %%
scientists.to_csv('output/scientists_df.tsv', sep='\t')

# %%
scientists.to_csv('output/scientists_df_no_index.csv', index=False)

# %%
scientists.to_csv('output/scientists_df_index.csv')

# %%
names_df = names.to_frame() # 시리즈는 데이터프레임으로 변환후에 엑셀로 저장 가능

import xlwt 
names_df.to_excel('output/scientists_names_series_df.xls')

import openpyxl 
names_df.to_excel('output/scientists_names_series_df.xlsx')

# %%
# pip install xlwt
# pip install openpyxl
