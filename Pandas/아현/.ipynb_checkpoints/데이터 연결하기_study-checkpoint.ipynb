# %% [markdown]
# 📖 참고, 데이터 : Do it! 데이터 분석을 위한 판다스 입문

# %% [markdown]
# # 데이터 연결하기

# %% [markdown]
# ### concat()으로 연결하기

# %%
import pandas as pd

# %% [markdown]
# - concat()은 데이터프레임을 연결할 때 위에서 아래 방향으로 연결함

# %%
df1 = pd.read_csv('data/concat_1.csv') 
df2 = pd.read_csv('data/concat_2.csv') 
df3 = pd.read_csv('data/concat_3.csv')

# %%
df1.head()
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df2.head()
# Out:
#     A   B   C   D
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
df3.head()
# Out:
#      A    B    C    D
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %% [markdown]
# ### 데이터프레임에 시리즈 연결하기

# %% [markdown]
# - NaN : 누락값

# %% [markdown]
# - 시리즈를 데이터프레임의 새로운 행으로 연결하려면 열 이름이 필요함

# %% [markdown]
# - concat()은 한 번에 2개 이상의 데이터프레임을 연결할 수 있는 메서드
# - 연결한 데이터프레임이 1개라면 append 메서드 사용 o

# %% [markdown]
# ### 다양한 방법으로 데이터 연결하기

# %% [markdown]
# - 보통 많이 쓰는 방법

# %% [markdown]
# # merge() 사용하기

# %% [markdown]
# - merge() : 기본적으로 내부 조인(둘 이상의 df에서 조건에 맞는 행을 연결하는 것)
