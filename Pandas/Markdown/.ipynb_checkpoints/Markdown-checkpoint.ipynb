# %% [markdown]
# # Markdown

# %% [markdown]
# - 파일 확장자 : .md
# - 문법이 쉬움
# - 관리가 쉬움
# - 지원 가능한 플랫폼과 프로그램이 다양함
# - 표준이 없음
# - 모든 HTML 마크업을 대신하지 못함

# %% [markdown]
# --------

# %% [markdown]
# # 1. 헤더

# %% [markdown]
# # H1 입니다
# ## H2 입니다
# ### H3 입니다
# #### H4 입니다
# ##### H5 입니다
# ###### H6 입니다

# %% [markdown]
# # 2. BlockQuote

# %% [markdown]
# > 첫 번째 BlockQuote
# >> 두 번째 BlockQuote

# %% [markdown]
# > 첫 번째 BlockQuote
# >> - 두 번째 BlockQuote

# %% [markdown]
# # 3. 목록

# %% [markdown]
# ## 순서가 있는 목록

# %% [markdown]
# 1. 첫 번째
# 2. 두 번째
# 3. 세 번째

# %% [markdown]
# ## 순서가 없는 목록(*, +, -)

# %% [markdown]
# - 안녕
#     * 안녕
#         + 안녕

# %% [markdown]
# # 4. 코드

# %% [markdown]
# <pre>
# <code>
# year = int(input("연도를 입력하시오: "))
#
# if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
#     print(year, "년은 윤년입니다.")
#
# else:
#     print(year, "년은 평년입니다.")
# </code>
# </pre>

# %% [markdown]
# ```python
# year = int(input("연도를 입력하시오: "))
#
# if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
#     print(year, "년은 윤년입니다.")
#
# else:
#     print(year, "년은 평년입니다.")
# ```

# %% [markdown]
# # 5. 수평선

# %% [markdown]
# <hr/>

# %% [markdown]
# ---

# %% [markdown]
# ***

# %% [markdown]
# # 6. 링크

# %% [markdown]
# [구글](https://google.com)
# 외부링크: <http://example.com/>

# %% [markdown]
# # 7. 강조

# %% [markdown]
# *이텔릭체*  _이텔릭체_
# **두껍게** __두껍게__
# ~~취소~~
# <u>밑줄</u>

# %% [markdown]
# # 8. 이미지

# %% [markdown]
# ![치킨](http://economychosun.com/query/upload/303/20190608214338_gubchoja.jpg)
# <img src="http://economychosun.com/query/upload/303/20190608214338_gubchoja.jpg" width="450px" height="300px" title="치킨" alt="치킨"></img>

# %% [markdown]
# # 9. 표

# %% [markdown]
# - 헤더 셀 구분할 때 3개 이상의 '-'가 필요
# - :로 셀 안에 내용을 정렬 할 수 있음

# %% [markdown]
# | 코드 | 의미 |
# |---|:---:|
# | `print` | 출력 |
# | `input` | 입력 |
# | `while` | 반복문 |
# | `if` | 조건문 |

# %% [markdown]
# # 10. 줄바꿈

# %% [markdown]
# - 띄어쓰기 2번
# - `<br>` 태그

# %% [markdown]
# 안녕<br>나는

# %% [markdown]
# # 11. 들여쓰기

# %% [markdown]
# &nbsp;&nbsp;&nbsp;안녕하세요
# 안녕하세요

# %% [markdown]
# # 12. 기타

# %% [markdown]
# || tool |
# | ------ | ------ |
# | 개발언어 | ![issue badge](https://img.shields.io/badge/python-3.7.4-blue.svg) ![issue badge](https://img.shields.io/badge/javascript-blue.svg) |
