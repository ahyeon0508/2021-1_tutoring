# %% [markdown]
# # 1.헤더

# %% [markdown]
# ## 작은 헤더

# %% [markdown]
# ### 더 작은 헤더

# %% [markdown]
# # 2. 들여쓰기

# %% [markdown]
# > 안녕하세요
# >> 나영이에요

# %% [markdown]
# # 3. 순서가 있는 목록

# %% [markdown]
# * 안녕
# ** 나는 나영이에요
# ** 만나서 반가워요

# %% [markdown]
# # 4. 코드

# %% [markdown]
# ```
# print("안녕하세요")
# ```

# %% [markdown]
# # 5.수평선

# %% [markdown]
# hr

# %% [markdown]
# # 6. 링크

# %% [markdown]
# [구글](https://www.google.com) <br>
# 외부링크 : <https:/www.naver.com>

# %% [markdown]
# # 7. 강조

# %% [markdown]
# *이텔릭체* _이텔릭체_
# **두껍게** __두껍게__
# ~~취소~~
# <u> 밑줄 <u>

# %% [markdown]
# # 8. 이미지

# %% [markdown]
# [치킨](https://www.mpps.co.kr/kfcs_api_img/KFCS/goods/DL_2174430_20210203113535665.png)<br>
# <img src="https://www.mpps.co.kr/kfcs_api_img/KFCS/goods/DL_2174430_20210203113535665.png" width="500px" height="300px" title="치킨" alt="치킨"></img>

# %% [markdown]
# # 9. 표

# %% [markdown]
# | 코드 | 의미 |
# |---|:---:|
# |'print' | 출력 |

# %% [markdown]
# # 10. 들여쓰기

# %% [markdown]
# 안녕
# 나는 <br>
# 나영이야 <br>
# &nbsp;&nbsp;&nbsp;안녕
