# %% [markdown]
# 📖 참고 : 이것이 데이터 분석이다 with 파이썬

# %% [markdown]
# # 멕시코풍 프랜차이즈 chipotle의 주문 데이터 분석하기

# %% [markdown]
# ## 1. 라이브러리 호출 및 데이터 읽기

# %%
import pandas as pd

# %%
chipo = pd.read_csv('../data/chipotle.tsv', sep='\t') # 지금까지는 데이터 위치가 같은 폴더내였지만 지금은 아남

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
print(chipo.shape) # 데이터의 행과 열의 크기 반환
print(chipo.info()) # 행의 구성 정보와 열의 구성 정보 나타내기
# Out:
# (4622, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB
# None

# %% [markdown]
# - order_id : 주문번호
# - quantity : 아이템의 주문 수량
# - item_name : 주문한 아이템의 이름
# - choice_description : 주문한 아이템의 상세 선택 옵션
# - item_price : 주문 아이템의 가격 정보

# %% [markdown]
# ## 2. EDA(탐색적 자료 분석)

# %% [markdown]
# ### 수치형 변수 기초 통계량 확인

# %%
chipo['order_id'] = chipo['order_id'].astype(str) # 채우기

# %%
chipo.describe() # 채우기 # 수치형 피처에 대해서만 기초 통계량을 확인할 수 있음
# Out:
#           quantity
# count  4622.000000
# mean      1.075725
# std       0.410186
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max      15.000000

# %% [markdown]
# => 평균이 약 1.07인 것을 보고 '한 사람이 같은 메뉴를 여러 개 구매하는 경우는 많지 않다'라는 것을 알 수 있다

# %% [markdown]
# ### 피처 내에 몇 개의 범주가 있는지 확인

# %%
print(len(chipo['order_id'].unique())) # order_id의 개수
print(len(chipo['item_name'].unique())) # item_name의 개수
# Out:
# 1834
# 50

# %% [markdown]
# ### 가장 많이 주문한 Top 10 출력하기

# %%
item_count = chipo['item_name'].value_counts()[:10]# 채우기

# %%
item_count
# Out:
# Chicken Bowl                    726
# Chicken Burrito                 553
# Chips and Guacamole             479
# Steak Burrito                   368
# Canned Soft Drink               301
# Chips                           211
# Steak Bowl                      211
# Bottled Water                   162
# Chicken Soft Tacos              115
# Chips and Fresh Tomato Salsa    110
# Name: item_name, dtype: int64

# %%
for idx, (val, cnt) in enumerate(item_count.iteritems()):
    print("Top", idx, ":", val, cnt)
# Out:
# Top 0 : Chicken Bowl 726
# Top 1 : Chicken Burrito 553
# Top 2 : Chips and Guacamole 479
# Top 3 : Steak Burrito 368
# Top 4 : Canned Soft Drink 301
# Top 5 : Chips 211
# Top 6 : Steak Bowl 211
# Top 7 : Bottled Water 162
# Top 8 : Chicken Soft Tacos 115
# Top 9 : Chips and Fresh Tomato Salsa 110

# %%
for idx, (val, cnt) in enumerate(item_count.iteritems(), 1):
    print("Top", idx, ":", val, cnt)
# Out:
# Top 1 : Chicken Bowl 726
# Top 2 : Chicken Burrito 553
# Top 3 : Chips and Guacamole 479
# Top 4 : Steak Burrito 368
# Top 5 : Canned Soft Drink 301
# Top 6 : Chips 211
# Top 7 : Steak Bowl 211
# Top 8 : Bottled Water 162
# Top 9 : Chicken Soft Tacos 115
# Top 10 : Chips and Fresh Tomato Salsa 110

# %% [markdown]
# ### 아이템 주문 개수와 총량

# %%
order_count = chipo.groupby('item_name')['order_id'].count()# 채우기
order_count
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# Chicken Salad Bowl                       110
# Chicken Soft Tacos                       115
# Chips                                    211
# Chips and Fresh Tomato Salsa             110
# Chips and Guacamole                      479
# Chips and Mild Fresh Tomato Salsa          1
# Chips and Roasted Chili Corn Salsa        22
# Chips and Roasted Chili-Corn Salsa        18
# Chips and Tomatillo Green Chili Salsa     43
# Chips and Tomatillo Red Chili Salsa       48
# Chips and Tomatillo-Green Chili Salsa     31
# Chips and Tomatillo-Red Chili Salsa       20
# Crispy Tacos                               2
# Izze                                      20
# Nantucket Nectar                          27
# Salad                                      2
# Side of Chips                            101
# Steak Bowl                               211
# Steak Burrito                            368
# Steak Crispy Tacos                        35
# Steak Salad                                4
# Steak Salad Bowl                          29
# Steak Soft Tacos                          55
# Veggie Bowl                               85
# Veggie Burrito                            95
# Veggie Crispy Tacos                        1
# Veggie Salad                               6
# Veggie Salad Bowl                         18
# Veggie Soft Tacos                          7
# Name: order_id, dtype: int64

# %%
item_quantity = chipo.groupby('item_name')['quantity'].count()# 채우기
item_quantity
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# Chicken Salad Bowl                       110
# Chicken Soft Tacos                       115
# Chips                                    211
# Chips and Fresh Tomato Salsa             110
# Chips and Guacamole                      479
# Chips and Mild Fresh Tomato Salsa          1
# Chips and Roasted Chili Corn Salsa        22
# Chips and Roasted Chili-Corn Salsa        18
# Chips and Tomatillo Green Chili Salsa     43
# Chips and Tomatillo Red Chili Salsa       48
# Chips and Tomatillo-Green Chili Salsa     31
# Chips and Tomatillo-Red Chili Salsa       20
# Crispy Tacos                               2
# Izze                                      20
# Nantucket Nectar                          27
# Salad                                      2
# Side of Chips                            101
# Steak Bowl                               211
# Steak Burrito                            368
# Steak Crispy Tacos                        35
# Steak Salad                                4
# Steak Salad Bowl                          29
# Steak Soft Tacos                          55
# Veggie Bowl                               85
# Veggie Burrito                            95
# Veggie Crispy Tacos                        1
# Veggie Salad                               6
# Veggie Salad Bowl                         18
# Veggie Soft Tacos                          7
# Name: quantity, dtype: int64

# %% [markdown]
# ### 시각화

# %% [markdown]
# x : 아이템 이름을 숫자로 라벨링, y : 아이템별 주문의 총량

# %%
import numpy as np
import matplotlib.pyplot as plt

item_name_list = item_quantity.index.tolist()
x_pos = np.arange(len(item_name_list))
order_cnt = item_quantity.values.tolist()

plt.bar(x_pos, order_cnt, align='center')
plt.ylabel('order_item_count')
plt.title('Distribution of all orderd item')

plt.show()

# %% [markdown]
# ## 3. 데이터 전처리

# %% [markdown]
# ### item_price를 수치형으로 바꾸기

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))# 채우기
chipo['item_price'].describe()
# Out:
# count    4622.000000
# mean        0.873466
# std         1.043397
# min         0.000000
# 25%         0.390000
# 50%         0.750000
# 75%         0.990000
# max         8.500000
# Name: item_price, dtype: float64

# %% [markdown]
# ## 4. EDA 심화

# %% [markdown]
# ### 주문당 평균 계산금액 출력하기

# %%
chipo.groupby('order_id')['item_price'].sum().mean()# 채우기
# Out:
# 2.2012868047982463

# %% [markdown]
# - 한 사람이 '약 18달러 가량의 주문을 할 것이다'라는 인사이트를 얻을 수 있음

# %% [markdown]
# ### 한 주문에 10달러 이상 지불한 주문 번호(id) 출력하기

# %%
# 채우기
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-abbea3db9b9a> in <module>
#       1 order_sum = chipo.groupby('order_id').sum()
# ----> 2 odrder_sumitem_price >=10
#
# NameError: name 'odrder_sumitem_price' is not defined

# %% [markdown]
# ### 각 아이템의 가격 구하기

# %%
chipo_one_item = chipo[chipo.quantity == 1]
price_per_item = chipo_one_item.groupby('item_name').min()
price_per_item.sort_values(by='item_price', ascending=False)[:10] # 10개만 출력
# Out:
#                                       order_id  quantity  \
# item_name
# Carnitas Salad                            1500         1
# Chips and Tomatillo Red Chili Salsa       1020         1
# Chips and Tomatillo Green Chili Salsa      102         1
# Chips and Roasted Chili Corn Salsa         102         1
# Veggie Salad Bowl                         1066         1
# Chicken Salad Bowl                        1015         1
# Steak Salad                               1406         1
# Side of Chips                             1002         1
# 6 Pack Soft Drink                         1076         1
# Chicken Crispy Tacos                      1010         1
#
#                                                                       choice_description  \
# item_name
# Carnitas Salad                         [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...
# Chips and Tomatillo Red Chili Salsa                                                  NaN
# Chips and Tomatillo Green Chili Salsa                                                NaN
# Chips and Roasted Chili Corn Salsa                                                   NaN
# Veggie Salad Bowl                      [Fresh Tomato Salsa, [Fajita Vegetables, Black...
# Chicken Salad Bowl                               [Fresh Tomato Salsa, Fajita Vegetables]
# Steak Salad                            [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# Side of Chips                                                                        NaN
# 6 Pack Soft Drink                                                                 [Coke]
# Chicken Crispy Tacos                         [Fresh Tomato Salsa (Mild), Fajita Veggies]
#
#                                        item_price
# item_name
# Carnitas Salad                               0.99
# Chips and Tomatillo Red Chili Salsa          0.95
# Chips and Tomatillo Green Chili Salsa        0.95
# Chips and Roasted Chili Corn Salsa           0.95
# Veggie Salad Bowl                            0.75
# Chicken Salad Bowl                           0.75
# Steak Salad                                  0.69
# Side of Chips                                0.69
# 6 Pack Soft Drink                            0.49
# Chicken Crispy Tacos                         0.49

# %% [markdown]
# ### 각 아이템의 가격 시각화

# %%
item_name_list = price_per_item.index.tolist()
x_pos = np.arange(len(item_name_list))
item_price = price_per_item['item_price'].tolist()

# %%
plt.bar(x_pos, item_price, align='center')
plt.ylabel('item price($)')
plt.title('Distribution of item price')
plt.show()

# %%
plt.hist(item_price)
plt.ylabel('counts')
plt.title('Histogram of item price')
plt.show()

# %%
item_price
# Out:
# [0.49,
#  0.25,
#  0.25,
#  0.25,
#  0.39,
#  0.25,
#  0.09,
#  0.4,
#  0.4,
#  0.09,
#  0.25,
#  0.25,
#  0.25,
#  0.25,
#  0.99,
#  0.39,
#  0.25,
#  0.19,
#  0.19,
#  0.49,
#  0.19,
#  0.75,
#  0.49,
#  0.15,
#  0.29,
#  0.0,
#  0.0,
#  0.95,
#  0.39,
#  0.95,
#  0.95,
#  0.39,
#  0.39,
#  0.4,
#  0.39,
#  0.39,
#  0.4,
#  0.69,
#  0.25,
#  0.25,
#  0.25,
#  0.69,
#  0.39,
#  0.25,
#  0.49,
#  0.49,
#  0.49,
#  0.49,
#  0.75,
#  0.49]

# %% [markdown]
# ### 가장 비싼 주문에서 아이템이 총 몇 개 팔렸는지 구하기

# %%
chipo.groupby('order_id').sum().sort_values(by='item_price',ascending=False)
# Out:
#           quantity  item_price
# order_id
# 1559            16       32.44
# 1449            11       31.39
# 1443            35       21.74
# 1786            20       18.30
# 511             17       17.59
# ...            ...         ...
# 1340             2        0.50
# 1372             2        0.50
# 355              2        0.50
# 1237             2        0.48
# 1042             3        0.39
#
# [1834 rows x 2 columns]

# %%
chipo.groupby('order_id').sum()
# Out:
#           quantity  item_price
# order_id
# 1                4        1.56
# 10               2        1.20
# 100              2        1.08
# 1000             2        1.50
# 1001             2        1.08
# ...            ...         ...
# 995              3        1.95
# 996              4        5.00
# 997              2        2.50
# 998              2        0.88
# 999              5        2.25
#
# [1834 rows x 2 columns]

# %% [markdown]
# ### 'Veggie Salad Bowl'이 몇 번 주문되었는지 구하기

# %%
chipo_salad= chipo[chipo['item_name'] == 'Veggie Salad Bowl']# 채우기

# 한 주문 내에서 중복 집계된 item_name을 제거
# chipo_salad = chipo_salad.drop_duplicates(['item_name', 'order_id'])

print(len(chipo_salad))
# Out:
# 18

# %% [markdown]
# ### 'Chicken Bowl'을 2개 이상 주문한 주문 횟수 구하기

# %%
chipo_chicken = chipo[chipo['item_name'] == 'Chicken Bowl']
print(len(chipo_chicken[chipo_chicken['quantity'] >= 2]))
# Out:
# 33
