# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
train_df = pd.read_excel('https://github.com/cranberryai/todak_todak_python/blob/master/machine_learning/binary_classification/%E1%84%83%E1%85%A1%E1%86%BC%E1%84%82%E1%85%AD_%E1%84%8E%E1%85%AC%E1%84%8C%E1%85%A9%E1%86%BC_jvyrMwR.xlsx?raw=true', sheet_name='train')
test_df = pd.read_excel('https://github.com/cranberryai/todak_todak_python/blob/master/machine_learning/binary_classification/%E1%84%83%E1%85%A1%E1%86%BC%E1%84%82%E1%85%AD_%E1%84%8E%E1%85%AC%E1%84%8C%E1%85%A9%E1%86%BC_jvyrMwR.xlsx?raw=true', sheet_name='test')

labels = ['정상', '당뇨']

# %%
train_df.head()
# Out:
#    ID  임신  글루코스(탄수화물 화합물)  혈압  피부두께  인슐린   BMI    가족력  나이  당뇨여부
# 0   1   6             148  72    35    0  33.6  0.627  50     1
# 1   3   1              89  66    23   94  28.1  0.167  21     0
# 2   4   0             137  40    35  168  43.1  2.288  33     1
# 3   6   2             197  70    45  543  30.5  0.158  53     1
# 4   8   5             166  72    19  175  25.8  0.587  51     1

# %%
test_df.head()
# Out:
#    ID  임신  글루코스(탄수화물 화합물)  혈압  피부두께  인슐린   BMI    가족력  나이  당뇨여부
# 0   2   1              85  66    29    0  26.6  0.351  31     0
# 1   5   3              78  50    32   88  31.0  0.248  26     1
# 2   7   1             189  60    23  846  30.1  0.398  59     1
# 3   9   0             118  84    47  230  45.8  0.551  31     1
# 4  10   1             103  30    38   83  43.3  0.183  33     0

# %%
print(len(test_df)); len(train_df)
# Out:
# 161
# 376

# %%
x_train = train_df.drop(['ID','당뇨여부'], axis = 1)
y_train = train_df['당뇨여부']

x_test = test_df.drop(['ID','당뇨여부'], axis = 1)
y_test = test_df['당뇨여부']

# %%
x_train.head()
# Out:
#    임신  글루코스(탄수화물 화합물)  혈압  피부두께  인슐린   BMI    가족력  나이
# 0   6             148  72    35    0  33.6  0.627  50
# 1   1              89  66    23   94  28.1  0.167  21
# 2   0             137  40    35  168  43.1  2.288  33
# 3   2             197  70    45  543  30.5  0.158  53
# 4   5             166  72    19  175  25.8  0.587  51

# %%
model = RandomForestClassifier(random_state = 3) # 모델 생성(랜덤으로 학습)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=3)

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test, y_test)
# Out:
# 0.7329192546583851

# %%
x_test = np.array([[5,130,30,30,800,33.6,0.127,25]])

# %%
y_predict = model.predict(x_test)

# %%
y_predict
# Out:
# array([0], dtype=int64)

# %%
label = labels[y_predict[0]]

# %%
label
# Out:
# '정상'

# %%
y_predict = model.predict_proba(x_test)

# %%
y_predict # 0.56 : 0.44
# Out:
# array([[0.56, 0.44]])

# %%
confidence = y_predict[0][y_predict[0].argmax()] #  np.argmax() 최대값인 색인 위치 , np.argmin() 최솟값 색인 위치

# %%
confidence
# Out:
# 0.56

# %%
y_predict[0].argmin()
# Out:
# 1

# %%
print(label, confidence)
# Out:
# 정상 0.56
